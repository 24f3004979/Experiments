# %% [markdown]
# # Visualising Mathematical concepts
# Making visual diagrams for Mathematical concepts using numpy, matplotlib and pandas based data generator tools

# %%
# Out:
# hi

# %%
import math
n = 1
x = []
for point in r:
    elem = math.sin(point * int(point))
    n += 1
    x.append(elem)

# Making Final Plot using pandas

points = {
    "x" : x,
}
points = pd.DataFrame(points)
points.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import numpy as np   

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x, y)

print(f"Final X and y for Z computation via sin and cos : {X,Y}")

Z = np.sin(X) * np.cos(Y)

plt.contourf(X, Y, Z, levels=50, cmap='viridis')
plt.colorbar()
plt.title('Filled Contour Plot')
plt.show()
# Out:
# Final X and y for Z computation via sin and cos : (array([[-2.        , -1.95959596, -1.91919192, ...,  1.91919192,
#          1.95959596,  2.        ],
#        [-2.        , -1.95959596, -1.91919192, ...,  1.91919192,
#          1.95959596,  2.        ],
#        [-2.        , -1.95959596, -1.91919192, ...,  1.91919192,
#          1.95959596,  2.        ],
#        ...,
#        [-2.        , -1.95959596, -1.91919192, ...,  1.91919192,
#          1.95959596,  2.        ],
#        [-2.        , -1.95959596, -1.91919192, ...,  1.91919192,
#          1.95959596,  2.        ],
#        [-2.        , -1.95959596, -1.91919192, ...,  1.91919192,
#          1.95959596,  2.        ]], shape=(100, 100)), array([[-2.        , -2.        , -2.        , ..., -2.        ,
#         -2.        , -2.        ],
#        [-1.95959596, -1.95959596, -1.95959596, ..., -1.95959596,
#         -1.95959596, -1.95959596],
#        [-1.91919192, -1.91919192, -1.91919192, ..., -1.91919192,
# ...

# %% [markdown]
# ## Mathematical Analysis tool kit
# Mathematical function analysis pipeline for basic data insights engine
# Raw data plots --> Picking up basic data structure based on majority --> Pipe for basic structure --> Final dataset
#
# Making Function fiting algorithm
#     > Deriving functional relation of the data points via analysing the pattern and making basic functional model for the data point , finalizing the relation modeling for final plot analysis
#
#     Analysis points
#     + Continuity and basic mathematical analysis of the function
#     + making basic functional key-charector, maxima, minima and function types
#     + Derivative nature and other extracts if possible
#
# defferentiability function could be made via making simple logic to satisfy the basic differentiation function via division by zero error catch way
